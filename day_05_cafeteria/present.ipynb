# %%
# %load_ext autoreload
# %autoreload 2
import solution
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
eg_ranges, eg_ids = solution.load_input(r"example.txt")
assert solution.count_fresh_ids(eg_ids, eg_ranges) == 3
print('Part 1 test passed example')
# Out:
# Part 1 test passed example

# %%
ranges, ids = solution.load_input(r"input.txt")
answer_p1 = solution.count_fresh_ids(ids, ranges)
print(f"Part 1 answer is {answer_p1}")
# Out:
# Part 1 answer is 513

# %%
assert solution.count_unique_fresh_ids(eg_ranges) == 14
print("Part II test passed example")
# Out:
# Part II test passed example

# %%
answer_p2 = solution.count_unique_fresh_ids(ranges)
print(f"Part II answer is {answer_p2}")
# Out:
# Part II answer is 339668510830757
