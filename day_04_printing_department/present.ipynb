# %%
# %load_ext autoreload
# %autoreload 2
import solution
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
grid = solution.read_input()

# %%
solution_part_1 = solution.count_accessible(grid)
print(f"solution_part_1 = {solution_part_1}")
# Out:
# solution_part_1 = 1602

# %%
solution_part_2 = solution.count_accessible_with_iter_remove(grid)
print(f"solution_part_2 = {solution_part_2}")
# Out:
# solution_part_2 = 9518
