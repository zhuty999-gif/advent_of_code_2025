# %%
# %load_ext autoreload
# %autoreload 2
import main
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Part I example solution
inp = main.load_input("example.txt")
dist_table = main.gen_distance_table(inp)
circ_yellowBook, circ_ids, _ = main.connect_circuits(inp, 10)
main.find_circLenProdSum(circ_ids)
# Out:
# 40

# %%
# Part I actual solution
inp = main.load_input("input.txt")
dist_table = main.gen_distance_table(inp)
circ_yellowBook, circ_ids, _ = main.connect_circuits(inp, 1000)
main.find_circLenProdSum(circ_ids)
# Out:
# 153328

# %%
# Part II example solution
inp = main.load_input("example.txt")
dist_table = main.gen_distance_table(inp)
circ_yellowBook, circ_ids, last_pair = main.connect_circuits(inp, stop_when_one_circuit=True)
print(last_pair)
print(last_pair[0].x * last_pair[1].x)
# Out:
# (Point3D(x=216, y=146, z=977), Point3D(x=117, y=168, z=530))
# 25272

# %%
# Part II actual solution
inp = main.load_input("input.txt")
dist_table = main.gen_distance_table(inp)
circ_yellowBook, circ_ids, last_pair = main.connect_circuits(inp, stop_when_one_circuit=True)
print(last_pair)
print(last_pair[0].x * last_pair[1].x)
# Out:
# (Point3D(x=71430, y=41887, z=1462), Point3D(x=85337, y=44242, z=3891))
# 6095621910
