# %%
# %load_ext autoreload
# %autoreload 2
import solution

# %%
input_text = solution.import_input_as_list()

# %%
largest_joltage_list = []
for bank in input_text:
    largest_joltage_step = solution.find_largest_joltage_from_a_bank(bank, 2)
    largest_joltage_list.append(largest_joltage_step)

answer_part_1 = sum(largest_joltage_list)
print(answer_part_1)
# Out:
# 17100

# %%
largest_joltage_list = []
for bank in input_text:
    largest_joltage_step = solution.find_largest_joltage_from_a_bank(bank, 12)
    largest_joltage_list.append(largest_joltage_step)

answer_part_2 = sum(largest_joltage_list)
print(answer_part_2)
# Out:
# 170418192256861
