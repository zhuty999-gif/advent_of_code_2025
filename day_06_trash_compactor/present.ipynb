# %%
# %load_ext autoreload
# %autoreload 2
import solution

# %%
inp = solution.read_input()

# %%
example_inp = solution.read_input('example.txt')
example_answer = solution.find_homework_answer(example_inp)
print(f"Example Answer: {example_answer}")
assert example_answer == 4277556, f"Expected 4277556, but got {example_answer}"
# Out:
# Example Answer: 4277556

# %%
part_1_answer = solution.find_homework_answer(inp)
print(f"Part I Answer: {part_1_answer}")
# Out:
# Part I Answer: 4583860641327

# %%
inp_promax = solution.read_input_promax()

# %%
solution.find_homework_answer_promax(inp_promax)
# Out:
# 11602774058280
